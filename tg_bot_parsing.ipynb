# %% [markdown]
# <a href="https://colab.research.google.com/github/ivanvsobolev-devops/Learning/blob/main/tg_bot_parsing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.olx.uz/nedvizhimost/"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")

ads = soup.select(".css-1g5933j")  # зависит от верстки

results = []

for ad in ads[:5]:
    title = ad.get_text(strip=True)
    link = ad.find("a")["href"]
    results.append((title, link))

results
# Out:
# [('Дача в горах, Бричмулла, Brichmulla, Бурчмулла, возле вдхр. Чарвак1 200 000 сумДоговорнаяЧарвак - 09 июня 2026 г.Подписаться',
#   '/d/obyavlenie/dacha-v-gorah-brichmulla-brichmulla-burchmulla-vozle-vdhr-charvak-ID3GBDZ.html'),
#  ('Своя квартира IT Park, ул Муминова 1в2/3/4  в кирпичном доме783 893 500 сумТашкент, Мирзо-Улугбекский район - 09 июня 2026 г.30Подписаться',
#   '/d/obyavlenie/svoya-kvartira-it-park-ul-muminova-1v2-3-4-v-kirpichnom-dome-ID4o853.html'),
#  ('Kunlik kvartira, hostel , hotel70 000 сумТашкент, Чиланзарский район - 08 июня 2026 г.Подписаться',
#   '/d/obyavlenie/kunlik-kvartira-hostel-hotel-ID3XsJx.html'),
#  ('Bez zaks kunlik mehmonxona|Hostel|Hotel| Kvartira| Toshkent| Гостиница100 000 сумТашкент, Алмазарский район - Сегодня в 04:28Подписаться',
#   '/d/obyavlenie/bez-zaks-kunlik-mehmonxona-hostel-hotel-kvartira-toshkent-gostinitsa-ID4kJb0.html'),
# ...
